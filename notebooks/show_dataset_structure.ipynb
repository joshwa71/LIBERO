# %%
import h5py
import os

def show_h5_tree(filepath, max_items=10):
    """Display h5py file structure like a directory tree"""
    
    def print_tree(name, obj, indent=""):
        # Print current item
        if isinstance(obj, h5py.Dataset):
            print(f"{indent}📊 {os.path.basename(name)} [{obj.shape}, {obj.dtype}]")
        elif isinstance(obj, h5py.Group):
            print(f"{indent}📁 {os.path.basename(name)}/")
            
            # Print children with increased indentation
            items = list(obj.items())
            if len(items) > max_items:
                print(f"{indent}  ... ({len(items)} items, showing first {max_items})")
                items = items[:max_items]
                
            for i, (key, subobj) in enumerate(items):
                is_last = (i == len(items) - 1)
                new_indent = indent + ("  " if is_last else "│ ")
                branch = "└─ " if is_last else "├─ "
                print_tree(f"{name}/{key}", subobj, indent + branch)
    
    print(f"📄 {os.path.basename(filepath)}")
    with h5py.File(filepath, 'r') as f:
        for key, obj in f.items():
            print_tree(key, obj, "├─ ")

# Try it on one of your files
demo_file = "/home/josh/phddev/LIBERO/datasets/datasets/libero_10/KITCHEN_SCENE6_put_the_yellow_and_white_mug_in_the_microwave_and_close_it_demo.hdf5"
show_h5_tree(demo_file, max_items=10)
# Out:
# 📄 KITCHEN_SCENE6_put_the_yellow_and_white_mug_in_the_microwave_and_close_it_demo.hdf5
# ├─ 📁 data/
# ├─   ... (50 items, showing first 10)
# ├─ ├─ 📁 demo_0/
# ├─ ├─ ├─ 📊 actions [(329, 7), float64]
# ├─ ├─ ├─ 📊 dones [(329,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(329, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(329, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(329, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(329, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(329, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(329, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(329, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(329,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(329, 9), float64]
# ├─ ├─ └─ 📊 states [(329, 47), float64]
# ├─ ├─ 📁 demo_1/
# ├─ ├─ ├─ 📊 actions [(248, 7), float64]
# ├─ ├─ ├─ 📊 dones [(248,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(248, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(248, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(248, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(248, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(248, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(248, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(248, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(248,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(248, 9), float64]
# ├─ ├─ └─ 📊 states [(248, 47), float64]
# ├─ ├─ 📁 demo_10/
# ├─ ├─ ├─ 📊 actions [(285, 7), float64]
# ├─ ├─ ├─ 📊 dones [(285,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(285, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(285, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(285, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(285, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(285, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(285, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(285, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(285,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(285, 9), float64]
# ├─ ├─ └─ 📊 states [(285, 47), float64]
# ├─ ├─ 📁 demo_11/
# ├─ ├─ ├─ 📊 actions [(253, 7), float64]
# ├─ ├─ ├─ 📊 dones [(253,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(253, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(253, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(253, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(253, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(253, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(253, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(253, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(253,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(253, 9), float64]
# ├─ ├─ └─ 📊 states [(253, 47), float64]
# ├─ ├─ 📁 demo_12/
# ├─ ├─ ├─ 📊 actions [(334, 7), float64]
# ├─ ├─ ├─ 📊 dones [(334,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(334, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(334, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(334, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(334, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(334, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(334, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(334, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(334,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(334, 9), float64]
# ├─ ├─ └─ 📊 states [(334, 47), float64]
# ├─ ├─ 📁 demo_13/
# ├─ ├─ ├─ 📊 actions [(310, 7), float64]
# ├─ ├─ ├─ 📊 dones [(310,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(310, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(310, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(310, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(310, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(310, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(310, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(310, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(310,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(310, 9), float64]
# ├─ ├─ └─ 📊 states [(310, 47), float64]
# ├─ ├─ 📁 demo_14/
# ├─ ├─ ├─ 📊 actions [(329, 7), float64]
# ├─ ├─ ├─ 📊 dones [(329,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(329, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(329, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(329, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(329, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(329, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(329, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(329, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(329,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(329, 9), float64]
# ├─ ├─ └─ 📊 states [(329, 47), float64]
# ├─ ├─ 📁 demo_15/
# ├─ ├─ ├─ 📊 actions [(316, 7), float64]
# ├─ ├─ ├─ 📊 dones [(316,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(316, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(316, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(316, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(316, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(316, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(316, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(316, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(316,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(316, 9), float64]
# ├─ ├─ └─ 📊 states [(316, 47), float64]
# ├─ ├─ 📁 demo_16/
# ├─ ├─ ├─ 📊 actions [(268, 7), float64]
# ├─ ├─ ├─ 📊 dones [(268,), uint8]
# ├─ ├─ ├─ 📁 obs/
# ├─ ├─ ├─ ├─ 📊 agentview_rgb [(268, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 ee_ori [(268, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_pos [(268, 3), float64]
# ├─ ├─ ├─ ├─ 📊 ee_states [(268, 6), float64]
# ├─ ├─ ├─ ├─ 📊 eye_in_hand_rgb [(268, 128, 128, 3), uint8]
# ├─ ├─ ├─ ├─ 📊 gripper_states [(268, 2), float64]
# ├─ ├─ ├─ └─ 📊 joint_states [(268, 7), float64]
# ├─ ├─ ├─ 📊 rewards [(268,), uint8]
# ├─ ├─ ├─ 📊 robot_states [(268, 9), float64]
# ├─ ├─ └─ 📊 states [(268, 47), float64]
# ├─ └─ 📁 demo_17/
# ├─ └─ ├─ 📊 actions [(279, 7), float64]
# ├─ └─ ├─ 📊 dones [(279,), uint8]
# ├─ └─ ├─ 📁 obs/
# ├─ └─ ├─ ├─ 📊 agentview_rgb [(279, 128, 128, 3), uint8]
# ├─ └─ ├─ ├─ 📊 ee_ori [(279, 3), float64]
# ├─ └─ ├─ ├─ 📊 ee_pos [(279, 3), float64]
# ├─ └─ ├─ ├─ 📊 ee_states [(279, 6), float64]
# ├─ └─ ├─ ├─ 📊 eye_in_hand_rgb [(279, 128, 128, 3), uint8]
# ├─ └─ ├─ ├─ 📊 gripper_states [(279, 2), float64]
# ├─ └─ ├─ └─ 📊 joint_states [(279, 7), float64]
# ├─ └─ ├─ 📊 rewards [(279,), uint8]
# ├─ └─ ├─ 📊 robot_states [(279, 9), float64]
# ├─ └─ └─ 📊 states [(279, 47), float64]
